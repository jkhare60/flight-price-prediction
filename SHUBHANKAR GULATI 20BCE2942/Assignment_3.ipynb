# %% [markdown]
# Name-Shubhankar Gulati
#
# 20BCE2942

# %% [markdown]
# **House Price Prediction**
# House price prediction is a common problem in the real estate industry and
# involves predicting the selling price of a house based on various features and attributes. The
# problem is typically approached as a regression problem, where the target variable is the price
# of the house, and the features are various attributes of the house
# The features used in house price prediction can include both quantitative and categorical
# variables, such as the number of bedrooms, house area, bedrooms, furnished, nearness to
# main road, and various amenities such as a garage and other factors that may influence the
# value of the property.
# Accurate predictions can help agents and appraisers price homes correctly, while
# homeowners can use the predictions to set a reasonable asking price for their properties.
# Accurate house price prediction can also be useful for buyers who are looking to make
# informed decisions about purchasing a property and obtaining a fair price for their
# investment

# %% [markdown]
# 2. Load the database

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-342ebbea-33fd-4f6a-9e4d-ff4b88687f4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-342ebbea-33fd-4f6a-9e4d-ff4b88687f4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['Housing.csv']))
print(df)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# 3. Perform Below Visualizations.

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# furnishingstatus    object
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = df["area"], palette="Dark2")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = df["price"], palette="Dark2")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
price_stats = df['price'].describe()
print(price_stats)
plt.hist(df['price'], bins=10, edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')
plt.show()
plt.boxplot(df['price'])
plt.ylabel('Price')
plt.title('Box Plot of Prices')
plt.show()
# Out:
# count    5.450000e+02
# mean     4.727388e+06
# std      1.745227e+06
# min      1.750000e+06
# 25%      3.430000e+06
# 50%      4.340000e+06
# 75%      5.740000e+06
# max      9.205000e+06
# Name: price, dtype: float64

# %%
from scipy.stats import chi2_contingency
contingency_table = pd.crosstab(df['price'], df['area'])
result = chi2_contingency(contingency_table)
chi2 = result[0]
p_value = result[1]
print("Chi-square:", chi2)
print("P-value:", p_value)
# Out:
# Chi-square: 57061.19328697194
# P-value: 0.9999999442484165

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.scatter(df['price'], df['area'])
plt.xlabel('Price')
plt.ylabel('Area')
plt.title('Scatter Plot: Price vs. Area')
plt.show()
plt.boxplot([df[df['mainroad'] == 'yes']['price'], df[df['mainroad'] == 'no']['price']], labels=['mainroad', 'Not mainroad'])
plt.ylabel('Price')
plt.title('Box Plot: Price by Mainroad')
plt.show()
grouped_data = df.groupby('furnishingstatus')['price'].mean()
grouped_data.plot(kind='bar')
plt.xlabel('Furnishing Status')
plt.ylabel('Average Price')
plt.title('Average Price by Furnishing Status')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df[['price', 'area', 'bedrooms', 'bathrooms']])
plt.show()

correlation = df[['price', 'area', 'bedrooms', 'bathrooms']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 4. perform descriptive statitics on the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
summary_stats = df.describe()
print(summary_stats)

count_non_null = df.count()
print(count_non_null)

unique_values = df.select_dtypes(include='object').nunique()
print(unique_values)

value_counts = df['price'].value_counts()
print(value_counts)
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.727388e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.745227e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    9.205000e+06  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     1.141284    1.822018    1.649541         1.954128         1.684404
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
##average of people survived
average=df['price'].mean()
print(average)
# Out:
# 4766729.247706422

# %%
##standard Deviation of people alive
std=df['price'].std()
print(std)
# Out:
# 1870439.6156573922

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
var1 = 'price'
var2 = 'area'
sns.kdeplot(data=df[var1], shade=True)

plt.xlabel(var1)
plt.ylabel(var2)
plt.title('Kernel Density Plot of ' + var1)
plt.show()
# Out:
# <ipython-input-108-578023095600>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[var1], shade=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style="whitegrid")
plt.figure(figsize=(10,8))
ax = sns.displot(x='price', data=df)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,10))
ax = sns.countplot(x='price', data=df)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,10))
ax = sns.countplot(x='area', data=df)

# %% [markdown]
# 5. Handle the Missing values.

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# 6. Find the outliers and replace the outliers

# %%
q1 = df["price"].quantile(0.25)
q2 = df["price"].quantile(0.75)
IQR = q2 - q1

# %%
#defining max and min limits
max_limit = q2 + (1.5 * IQR)
min_limit = q1 - (1.5 * IQR)

# %%
import numpy as np
df_new = pd.DataFrame(np.where(df["price"] > max_limit, max_limit, 
         (np.where(df["price"] < min_limit, min_limit, df["price"]))), columns=["price"])

# %%
plt.figure(figsize=(8,5))
plt.suptitle("Distribution with Outliers", fontsize=18)
plt.subplot(1,2,1)
sns.kdeplot(data = df['price'], palette="cool")
plt.subplot(1,2,2)
sns.boxplot(data = df['price'], palette="Dark2")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-31814e1bc0ab>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data = df['price'], palette="cool")

# %%
plt.figure(figsize=(8,5))
plt.suptitle("Distribution after handling outliers",fontsize=18)
plt.subplot(1,2,1)
sns.kdeplot(data = df_new, palette="cool")
plt.subplot(1,2,2)
sns.boxplot(data = df_new, palette="Dark2")
plt.tight_layout()
plt.show()

# %%
df['price']=df_new

# %% [markdown]
# 7. Check for Categorical columns and perform encoding.

# %%
df.select_dtypes(include=['object'])
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning  \
# 0        yes        no       no              no             yes
# 1        yes        no       no              no             yes
# 2        yes        no      yes              no              no
# 3        yes        no      yes              no             yes
# 4        yes       yes      yes              no             yes
# ..       ...       ...      ...             ...             ...
# 540      yes        no      yes              no              no
# 541       no        no       no              no              no
# 542      yes        no       no              no              no
# 543       no        no       no              no              no
# 544      yes        no       no              no              no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# ..               ...
# 540      unfurnished
# ...

# %%
df['mainroad'].value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %%
df['guestroom'].value_counts()
# Out:
# no     448
# yes     97
# Name: guestroom, dtype: int64

# %%
df['basement'].value_counts()
# Out:
# no     354
# yes    191
# Name: basement, dtype: int64

# %%
df['hotwaterheating'].value_counts()
# Out:
# no     520
# yes     25
# Name: hotwaterheating, dtype: int64

# %%
df['airconditioning'].value_counts()
# Out:
# no     373
# yes    172
# Name: airconditioning, dtype: int64

# %%
df['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
df.select_dtypes(include=['object'])
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning  \
# 0        yes        no       no              no             yes
# 1        yes        no       no              no             yes
# 2        yes        no      yes              no              no
# 3        yes        no      yes              no             yes
# 4        yes       yes      yes              no             yes
# ..       ...       ...      ...             ...             ...
# 540      yes        no      yes              no              no
# 541       no        no       no              no              no
# 542      yes        no       no              no              no
# 543       no        no       no              no              no
# 544      yes        no       no              no              no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# ..               ...
# 540      unfurnished
# ...

# %%
cleanup_nums = {"mainroad":     {"yes": 1, "no": 2},
                "guestroom": {"yes": 1, "no": 2},
                "basement": {"yes": 1, "no": 2},
                "hotwaterheating":{"yes": 1, "no": 2},
                "airconditioning":{"yes": 1, "no": 2},
                "furnishingstatus":{"furnished":1,"unfurnished":3,"semi-furnished":2}}

# %%
df = df.replace(cleanup_nums)
df.head()
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  9205000.0  7420         4          2        3         1          2
# 1  9205000.0  8960         4          4        4         1          2
# 2  9205000.0  9960         3          2        2         1          2
# 3  9205000.0  7500         4          2        2         1          2
# 4  9205000.0  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 0         2                2                1        2                 1
# 1         2                2                1        3                 1
# 2         1                2                2        2                 2
# 3         1                2                1        3                 1
# 4         1                2                1        2                 1

# %%
df.dtypes
# Out:
# price               float64
# area                  int64
# bedrooms              int64
# bathrooms             int64
# stories               int64
# mainroad              int64
# guestroom             int64
# basement              int64
# hotwaterheating       int64
# airconditioning       int64
# parking               int64
# furnishingstatus      int64
# dtype: object

# %% [markdown]
# 8. Split the data into dependent and independent variables

# %%
import pandas as pd

X = df.drop('price', axis=1) 
y = df['price']  
print('Independent variables are:', X.head())
print('Dependent variables are:', y.head())
print('Shape of Independent variables is:',X.shape)
print('Shape of Dependent variables is:',y.shape)
# Out:
# Independent variables are:    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          2         2
# 1  8960         4          4        4         1          2         2
# 2  9960         3          2        2         1          2         1
# 3  7500         4          2        2         1          2         1
# 4  7420         4          1        2         1          1         1
#
#    hotwaterheating  airconditioning  parking  furnishingstatus
# 0                2                1        2                 1
# 1                2                1        3                 1
# 2                2                2        2                 2
# 3                2                1        3                 1
# 4                2                1        2                 1
# Dependent variables are: 0    9205000.0
# 1    9205000.0
# 2    9205000.0
# 3    9205000.0
# 4    9205000.0
# Name: price, dtype: float64
# ...

# %% [markdown]
# 9. Scale the independent variables

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[ 1.04672629  1.40341936  1.42181174 ... -1.4726183   1.51769249
#   -1.40628573]
#  [ 1.75700953  1.40341936  5.40580863 ... -1.4726183   2.67940935
#   -1.40628573]
#  [ 2.21823241  0.04727831  1.42181174 ...  0.67906259  1.51769249
#   -0.09166185]
#  ...
#  [-0.70592066 -1.30886273 -0.57018671 ...  0.67906259 -0.80574124
#    1.22296203]
#  [-1.03338891  0.04727831 -0.57018671 ...  0.67906259 -0.80574124
#   -1.40628573]
#  [-0.5998394   0.04727831 -0.57018671 ...  0.67906259 -0.80574124
#    1.22296203]]

# %% [markdown]
# 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2, random_state=25)

print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 436
# No. of testing examples: 109

# %% [markdown]
# 11. Build the Model

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
num_vars = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking','price','furnishingstatus']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 296  0.328638  0.202749      0.25   0.333333  0.333333         1          2
# 150  0.516432  0.239588      0.25   0.000000  0.333333         1          1
# 195  0.431925  0.189691      0.50   0.666667  0.333333         1          2
# 158  0.502347  0.435052      0.25   0.000000  0.000000         1          2
# 510  0.103286  0.084536      0.25   0.000000  0.000000         2          2
#
#      basement  hotwaterheating  airconditioning   parking  furnishingstatus
# 296         2                2                1  0.333333               0.5
# 150         1                2                1  0.000000               1.0
# 195         1                2                2  0.666667               0.5
# 158         2                2                2  0.666667               0.5
# 510         2                2                2  0.000000               1.0

# %%
df_train.describe()
# Out:
#             price        area    bedrooms   bathrooms     stories    mainroad  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean     0.397819    0.242209    0.246560    0.095566    0.269113    1.146789
# std      0.236762    0.149412    0.184888    0.165446    0.284022    0.354302
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.225352    0.129553    0.250000    0.000000    0.000000    1.000000
# 50%      0.349765    0.205223    0.250000    0.000000    0.333333    1.000000
# 75%      0.535211    0.328351    0.250000    0.333333    0.333333    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    2.000000
#
#         guestroom    basement  hotwaterheating  airconditioning     parking  \
# count  436.000000  436.000000       436.000000       436.000000  436.000000
# mean     1.823394    1.653670         1.949541         1.708716    0.233180
# ...

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
y_train = df_train.pop('price')
X_train = df_train

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
rfe = RFE(lm, step = 6)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', True, 1),
#  ('bedrooms', False, 2),
#  ('bathrooms', True, 1),
#  ('stories', True, 1),
#  ('mainroad', False, 2),
#  ('guestroom', False, 2),
#  ('basement', False, 2),
#  ('hotwaterheating', True, 1),
#  ('airconditioning', True, 1),
#  ('parking', False, 2),
#  ('furnishingstatus', False, 2)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['area', 'bathrooms', 'stories', 'hotwaterheating', 'airconditioning'], dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['bedrooms', 'mainroad', 'guestroom', 'basement', 'parking',
#        'furnishingstatus'],
#       dtype='object')

# %%
X_train_rfe = X_train[col]

# %%
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %% [markdown]
# 12. Train the Model

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     129.5
# Date:                Tue, 06 Jun 2023   Prob (F-statistic):           1.97e-83
# Time:                        18:52:55   Log-Likelihood:                 210.20
# No. Observations:                 436   AIC:                            -408.4
# Df Residuals:                     430   BIC:                            -383.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.6486      0.080      8.150      0.000       0.492       0.805
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
X = X_train_rfe
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features     VIF
# 0            const  122.01
# 3          stories    1.22
# 2        bathrooms    1.21
# 5  airconditioning    1.19
# 1             area    1.10
# 4  hotwaterheating    1.04

# %% [markdown]
# 13. Test the Model

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
X_test = sm.add_constant(X_test)

# %%
X_test_rfe = X_test[X_train_rfe.columns]

# %%
y_pred = lm.predict(X_test_rfe)

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# -8.229331064260961

# %% [markdown]
# 14. Measure the performance using Metrics

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')

# %%
from sklearn.metrics import mean_absolute_error
print("MAE= ",mean_absolute_error(y_test,y_pred))
# Out:
# MAE=  4770583.274256418

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("MAPE= ",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# MAPE=  0.9992565752186738

# %%
from sklearn.metrics import r2_score
print("R2= ",r2_score(y_test,y_pred))
# Out:
# R2=  -8.229331064260961

# %%
import pandas as pd

from sklearn.metrics import mean_squared_error, r2_score
linear_mse = mean_squared_error(y_test, y_pred)
print("MSE:", linear_mse)
# Out:
# MSE: 25521517007299.28
